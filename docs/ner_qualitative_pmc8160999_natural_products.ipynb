# %%
import numpy
print(numpy.__version__)
# Out:
# 2.0.2

# %%
# !pip install "spacy>=3.8" "thinc>=8.3" flair --quiet
# !pip install --no-deps https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bc5cdr_md-0.5.4.tar.gz --quiet
# !pip install --no-deps https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_jnlpba_md-0.5.4.tar.gz --quiet
# !pip install --no-deps https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bionlp13cg_md-0.5.4.tar.gz --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.1/203.1 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 49.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.2/129.2 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 90.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 8.9 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done
#   Building wheel for pptree (setup.py) ... done
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 6.19.0 requires huggingface-hub<2.0,>=1.2.0, but you have huggingface-hub 0.36.2 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for en_ner_bc5cdr_md (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for en_ner_jnlpba_md (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for en_ner_bionlp13cg_md (setup.py) ... done

# %%
import flair
print(flair.__version__)
# Out:
# 0.15.1

# %%
import en_ner_bc5cdr_md, os
pkg_dir = os.path.dirname(en_ner_bc5cdr_md.__file__)
print(pkg_dir)
# !find {pkg_dir} -name "config.cfg"
# Out:
# /usr/local/lib/python3.12/dist-packages/en_ner_bc5cdr_md
# /usr/local/lib/python3.12/dist-packages/en_ner_bc5cdr_md/en_ner_bc5cdr_md-0.5.4/config.cfg
# /usr/local/lib/python3.12/dist-packages/spacy/util.py:971: UserWarning: [W095] Model 'en_ner_bc5cdr_md' (0.5.4) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.14). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
import subprocess

for pkg_name in ["en_ner_bc5cdr_md", "en_ner_jnlpba_md", "en_ner_bionlp13cg_md"]:
    mod = __import__(pkg_name)
    pkg_dir = os.path.dirname(mod.__file__)
    result = subprocess.run(["find", pkg_dir, "-name", "config.cfg"], capture_output=True, text=True)
    config_paths = result.stdout.strip().split("\n")
    for path in config_paths:
        if not path:
            continue
        print("Patching:", path)
        # !sed -i 's/include_static_vectors = "True"/include_static_vectors = true/' "{path}"
        # !sed -i 's/include_static_vectors = "False"/include_static_vectors = false/' "{path}"
# Out:
# Patching: /usr/local/lib/python3.12/dist-packages/en_ner_bc5cdr_md/en_ner_bc5cdr_md-0.5.4/config.cfg
# Patching: /usr/local/lib/python3.12/dist-packages/en_ner_jnlpba_md/en_ner_jnlpba_md-0.5.4/config.cfg
# /usr/local/lib/python3.12/dist-packages/spacy/util.py:971: UserWarning: [W095] Model 'en_ner_jnlpba_md' (0.5.4) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.14). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Patching: /usr/local/lib/python3.12/dist-packages/en_ner_bionlp13cg_md/en_ner_bionlp13cg_md-0.5.4/config.cfg
# /usr/local/lib/python3.12/dist-packages/spacy/util.py:971: UserWarning: [W095] Model 'en_ner_bionlp13cg_md' (0.5.4) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.14). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
import numpy
import spacy
import flair
print("numpy:", numpy.__version__)
print("spacy:", spacy.__version__)
print("flair:", flair.__version__)

nlp_test = spacy.load("en_ner_bc5cdr_md")
print("bc5cdr model loaded OK:", nlp_test.pipe_names)
# Out:
# numpy: 2.0.2
# spacy: 3.8.14
# flair: 0.15.1
# /usr/local/lib/python3.12/dist-packages/spacy/util.py:971: UserWarning: [W095] Model 'en_ner_bc5cdr_md' (0.5.4) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.14). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.12/dist-packages/spacy/language.py:2235: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# bc5cdr model loaded OK: ['tok2vec', 'tagger', 'attribute_ruler', 'lemmatizer', 'parser', 'ner']

# %%
import random
import re

import requests
import spacy
import torch
import flair
from flair.nn import Classifier
from flair.data import Sentence

# %%
# Must run before any model is loaded — flair reads this global at load time.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

flair.device = device
# Out:
# Using device: cuda

# %%
def load_sentences_from_pmc(pmcid, max_sentences=None, seed=42):
    """
    Download an Open Access PMC article, extract its text from BioC JSON,
    and split it into sentences.
    """
    url = (
        "https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/"
        f"pmcoa.cgi/BioC_json/{pmcid}/unicode"
    )

    resp = requests.get(url)
    resp.raise_for_status()
    data = resp.json()

    collection = data[0] if isinstance(data, list) else data
    documents = collection.get("documents", [])

    text_parts = []
    for doc in documents:
        for passage in doc.get("passages", []):
            text = passage.get("text", "").strip()
            if text:
                text_parts.append(text)

    full_text = re.sub(r"\s+", " ", "\n".join(text_parts)).strip()

    sentencizer = spacy.blank("en")
    sentencizer.add_pipe("sentencizer")
    doc = sentencizer(full_text)

    sentences = [
        sent.text.strip()
        for sent in doc.sents
        if len(sent.text.strip()) > 20
    ]

    if max_sentences and len(sentences) > max_sentences:
        random.seed(seed)
        sentences = random.sample(sentences, max_sentences)

    return sentences

# %%
FALLBACK_SENTENCES = [
    "SIRT1 activation reduces inflammation in hippocampus tissue and is "
    "associated with reduced risk of Alzheimer's disease.",
    "Metformin reduces symptoms of type 2 diabetes by activating AMPK.",
    "Overexpression of HER2 was observed in breast tissue biopsies from "
    "patients with invasive ductal carcinoma of the mammary gland.",
    "Transcription of the target mRNA was suppressed in Jurkat T cells "
    "following siRNA knockdown of the corresponding DNA sequence.",
    "The p.Val600Glu mutation in BRAF was associated with treatment "
    "resistance in melanoma patients.",
    "Resveratrol activates SIRT1 but not mTOR signaling in skeletal muscle.",
]

# %%
print("Loading scispaCy bc5cdr...", flush=True)
nlp_bc5 = spacy.load("en_ner_bc5cdr_md")
print("  -> done", flush=True)
# Out:
# Loading scispaCy bc5cdr...
#   -> done

# %%
print("Loading scispaCy jnlpba...", flush=True)
nlp_jnl = spacy.load("en_ner_jnlpba_md")
print("  -> done", flush=True)
# Out:
# Loading scispaCy jnlpba...
# /usr/local/lib/python3.12/dist-packages/spacy/util.py:971: UserWarning: [W095] Model 'en_ner_jnlpba_md' (0.5.4) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.14). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
#   -> done

# %%
print("Loading scispaCy bionlp13cg...", flush=True)
nlp_bio = spacy.load("en_ner_bionlp13cg_md")
print("  -> done", flush=True)
# Out:
# Loading scispaCy bionlp13cg...
# /usr/local/lib/python3.12/dist-packages/spacy/util.py:971: UserWarning: [W095] Model 'en_ner_bionlp13cg_md' (0.5.4) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.14). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
#   -> done

# %%
print("Loading HunFlair2 (GPU if available)...", flush=True)
hunflair = Classifier.load("hunflair2")  # loads onto flair.device automatically
print("  -> done", flush=True)
# Out:
# Loading HunFlair2 (GPU if available)...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/434M [00:00<?, ?B/s]
# 2026-07-11 15:16:14,586 SequenceTagger predicts: Dictionary with 21 tags: O, S-Chemical, B-Chemical, E-Chemical, I-Chemical, S-Gene, B-Gene, E-Gene, I-Gene, S-Disease, B-Disease, E-Disease, I-Disease, S-Species, B-Species, E-Species, I-Species, S-CellLine, B-CellLine, E-CellLine, I-CellLine
#   -> done

# %%
def run_scispacy(nlp, text, source_name):
    doc = nlp(text)
    return [
        {
            "source": source_name,
            "text": ent.text,
            "label": ent.label_,
            "start": ent.start_char,
            "end": ent.end_char,
        }
        for ent in doc.ents
    ]


def run_hunflair2(hunflair, text):
    sentence = Sentence(text)
    hunflair.predict(sentence)
    results = []
    for ent in sentence.get_spans("ner"):
        results.append(
            {
                "source": "hunflair2",
                "text": ent.text,
                "label": ent.get_label("ner").value,
                "start": ent.start_position,
                "end": ent.end_position,
                "confidence": round(ent.get_label("ner").score, 3),
            }
        )
    return results

# %%
def print_comparison(sentence_idx, text, all_results):
    print("\n" + "=" * 100)
    print(f"SENTENCE {sentence_idx + 1}: {text}")
    print("=" * 100)

    by_source = {}
    for r in all_results:
        by_source.setdefault(r["source"], []).append(r)

    for source in ["scispacy_bc5cdr", "scispacy_jnlpba", "scispacy_bionlp13cg", "hunflair2"]:
        ents = by_source.get(source, [])
        print(f"\n  [{source}]  ({len(ents)} entities)")
        if not ents:
            print("      (none found)")
        for e in sorted(ents, key=lambda x: x["start"]):
            conf = f"  conf={e['confidence']}" if "confidence" in e else ""
            print(f"      '{e['text']}'  ->  {e['label']}{conf}  [{e['start']}:{e['end']}]")

    # Flag spans only one model caught (useful for spotting real coverage gaps)
    all_spans = [(e["start"], e["end"], e["source"]) for e in all_results]
    span_sources = {}
    for start, end, source in all_spans:
        span_sources.setdefault((start, end), set()).add(source)

    unique_catches = {k: v for k, v in span_sources.items() if len(v) == 1}
    if unique_catches:
        print("\n  --- Caught by only ONE model (possible coverage gap elsewhere) ---")
        for (start, end), sources in unique_catches.items():
            matching = [e for e in all_results if e["start"] == start and e["end"] == end]
            if matching:
                e = matching[0]
                print(f"      '{e['text']}' ({e['label']}) — only {list(sources)[0]}")

# %%
PMCID = "PMC8160999"     # Change to any Open Access PMC ID
MAX_SENTENCES = 100
SEED = 42

sentences = load_sentences_from_pmc(PMCID, max_sentences=MAX_SENTENCES, seed=SEED)
print(f"Loaded {len(sentences)} sentences from {PMCID}")
# Out:
# Loaded 100 sentences from PMC8160999

# %%
for idx, text in enumerate(sentences):
    results = []
    results += run_scispacy(nlp_bc5, text, "scispacy_bc5cdr")
    results += run_scispacy(nlp_jnl, text, "scispacy_jnlpba")
    results += run_scispacy(nlp_bio, text, "scispacy_bionlp13cg")
    results += run_hunflair2(hunflair, text)

    print_comparison(idx, text, results)

print("\n" + "=" * 100)
print("Done.")
print("=" * 100)
# Out:
# ====================================================================================================
# SENTENCE 1: The potential anticancer mechanisms of 6-Shogaol were attributed to the nuclear DNA fragmentation, increased sub G1 population, activation of the intrinsic caspase pathway, and PARP cleavage.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       '6-Shogaol'  ->  CHEMICAL  [39:48]
#
#   [scispacy_jnlpba]  (1 entities)
#       'PARP'  ->  PROTEIN  [177:181]
#
#   [scispacy_bionlp13cg]  (5 entities)
#       'anticancer'  ->  CANCER  [14:24]
#       '6-Shogaol'  ->  SIMPLE_CHEMICAL  [39:48]
#       'nuclear DNA'  ->  CELLULAR_COMPONENT  [72:83]
#       'caspase'  ->  GENE_OR_GENE_PRODUCT  [156:163]
#       'PARP'  ->  GENE_OR_GENE_PRODUCT  [177:181]
#
#   [hunflair2]  (3 entities)
#       '6-Shogaol'  ->  Chemical  conf=1.0  [39:48]
#       'caspase'  ->  Gene  conf=0.999  [156:163]
#       'PARP'  ->  Gene  conf=1.0  [177:181]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'anticancer' (CANCER) — only scispacy_bionlp13cg
#       'nuclear DNA' (CELLULAR_COMPONENT) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 2: This Special Issue comprises of 13 research articles on bioactive compounds from plants, animals, and microbial sources that exemplify their bio-techno-functional properties to play a beneficial role in agri-food-pharma sector with valuable applications to benefit human health.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (1 entities)
#       'agri-food-pharma sector'  ->  PROTEIN  [203:226]
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'human'  ->  ORGANISM  [265:270]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'agri-food-pharma sector' (PROTEIN) — only scispacy_jnlpba
#       'human' (ORGANISM) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 3: Understanding the molecular characteristics, physicochemical properties, biological activity, and stability of these bioactives under different conditions is vital for their commercial exploitation.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 4: These hydrolyzed proteins improved the encapsulation efficiency of flavonoids.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'flavonoids'  ->  CHEMICAL  [67:77]
#
#   [scispacy_jnlpba]  (1 entities)
#       'hydrolyzed proteins'  ->  PROTEIN  [6:25]
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'flavonoids'  ->  SIMPLE_CHEMICAL  [67:77]
#
#   [hunflair2]  (1 entities)
#       'flavonoids'  ->  Chemical  conf=1.0  [67:77]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'hydrolyzed proteins' (PROTEIN) — only scispacy_jnlpba
#
# ====================================================================================================
# SENTENCE 5: These antimicrobial siderophores acted as effective chelating agents with transition metals, forming soluble complexes with Fe3+.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'Fe3+'  ->  SIMPLE_CHEMICAL  [124:128]
#
#   [hunflair2]  (1 entities)
#       'Fe3+'  ->  Chemical  conf=1.0  [124:128]
#
# ====================================================================================================
# SENTENCE 6: The authors formulated agar–agar (Agr) and gelatin (GE) copolymerized methyl acrylate (MA) and acrylic acid (AA) hydrogels (Agr/GE-co-MA/AA) by utilizing microwave-assisted green synthesis.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (4 entities)
#       'Agr'  ->  CHEMICAL  [34:37]
#       'methyl acrylate'  ->  CHEMICAL  [70:85]
#       'acrylic acid'  ->  CHEMICAL  [95:107]
#       'AA) hydrogels'  ->  CHEMICAL  [109:122]
#
#   [scispacy_jnlpba]  (2 entities)
#       'gelatin (GE) copolymerized methyl acrylate (MA)'  ->  PROTEIN  [43:90]
#       'Agr/GE-co-MA/AA'  ->  CELL_LINE  [124:139]
#
#   [scispacy_bionlp13cg]  (5 entities)
#       'Agr'  ->  GENE_OR_GENE_PRODUCT  [34:37]
#       'methyl acrylate'  ->  SIMPLE_CHEMICAL  [70:85]
#       'MA'  ->  GENE_OR_GENE_PRODUCT  [87:89]
#       'acrylic acid'  ->  SIMPLE_CHEMICAL  [95:107]
#       'green'  ->  SIMPLE_CHEMICAL  [173:178]
#
#   [hunflair2]  (11 entities)
#       'agar–agar'  ->  Chemical  conf=0.999  [23:32]
#       'Agr'  ->  Chemical  conf=1.0  [34:37]
#       'gelatin'  ->  Chemical  conf=0.52  [43:50]
#       'GE'  ->  Chemical  conf=1.0  [52:54]
#       'methyl acrylate'  ->  Chemical  conf=1.0  [70:85]
#       'MA'  ->  Chemical  conf=1.0  [87:89]
#       'acrylic acid'  ->  Chemical  conf=1.0  [95:107]
#       'AA'  ->  Chemical  conf=1.0  [109:111]
#       'Agr'  ->  Chemical  conf=1.0  [124:127]
#       'GE-co-MA'  ->  Chemical  conf=0.971  [128:136]
#       'AA'  ->  Chemical  conf=1.0  [137:139]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'AA) hydrogels' (CHEMICAL) — only scispacy_bc5cdr
#       'gelatin (GE) copolymerized methyl acrylate (MA)' (PROTEIN) — only scispacy_jnlpba
#       'Agr/GE-co-MA/AA' (CELL_LINE) — only scispacy_jnlpba
#       'green' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#       'agar–agar' (Chemical) — only hunflair2
#       'gelatin' (Chemical) — only hunflair2
#       'GE' (Chemical) — only hunflair2
#       'AA' (Chemical) — only hunflair2
#       'Agr' (Chemical) — only hunflair2
#       'GE-co-MA' (Chemical) — only hunflair2
#       'AA' (Chemical) — only hunflair2
#
# ====================================================================================================
# SENTENCE 7: This study demonstrated that A. cordifolia could be a suitable plant source to further investigate the mechanism of action of the bioactive compounds present (as antioxidant and anticancer agents) for potential pharmaceutical applications.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'A. cordifolia'  ->  DISEASE  [29:42]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (2 entities)
#       'A. cordifolia'  ->  ORGANISM  [29:42]
#       'anticancer'  ->  CANCER  [178:188]
#
#   [hunflair2]  (1 entities)
#       'A. cordifolia'  ->  Species  conf=1.0  [29:42]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'anticancer' (CANCER) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 8: This search highlighted enhanced interest in the development of novel nanoformulation strategies for many kinds of bioactive agents.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 9: References Valorization of fruits and vegetable wastes and by-products to produce natural pigments Extraction of Carotenoids from Pumpkin Peel and Pulp: Comparison between Innovative Green Extraction Technologies (Ultrasonic and Microwave-Assisted Extractions Using Corn Oil) Deeper Insights on Alchornea cordifolia (Schumach. &
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'Alchornea cordifolia'  ->  CHEMICAL  [295:315]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (7 entities)
#       'fruits'  ->  ORGANISM_SUBDIVISION  [27:33]
#       'vegetable'  ->  ORGANISM_SUBDIVISION  [38:47]
#       'by-products'  ->  SIMPLE_CHEMICAL  [59:70]
#       'Carotenoids'  ->  SIMPLE_CHEMICAL  [113:124]
#       'Pulp'  ->  TISSUE  [147:151]
#       'Corn Oil'  ->  CELL  [266:274]
#       'Schumach'  ->  ORGANISM  [317:325]
#
#   [hunflair2]  (4 entities)
#       'Carotenoids'  ->  Chemical  conf=1.0  [113:124]
#       'Pumpkin'  ->  Species  conf=1.0  [130:137]
#       'Corn Oil'  ->  Chemical  conf=0.999  [266:274]
#       'Alchornea cordifolia'  ->  Species  conf=1.0  [295:315]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'fruits' (ORGANISM_SUBDIVISION) — only scispacy_bionlp13cg
#       'vegetable' (ORGANISM_SUBDIVISION) — only scispacy_bionlp13cg
#       'by-products' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#       'Pulp' (TISSUE) — only scispacy_bionlp13cg
#       'Schumach' (ORGANISM) — only scispacy_bionlp13cg
#       'Pumpkin' (Species) — only hunflair2
#
# ====================================================================================================
# SENTENCE 10: Additionally, it highlights the novel nano-formulations strategies that have been developed to enhance the bioactive potential of biobased compounds in food, agriculture, and pharmaceutical applications.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'nano-formulations'  ->  SIMPLE_CHEMICAL  [38:55]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'nano-formulations' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 11: This study provided knowledge about the binding affinity and interaction mechanism of native and cross-linked proteins at different temperatures (25 to 95 °C).
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (1 entities)
#       'cross-linked proteins'  ->  PROTEIN  [97:118]
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'cross-linked proteins' (PROTEIN) — only scispacy_jnlpba
#
# ====================================================================================================
# SENTENCE 12: Authors (M.S. and R.B.) acknowledge ERA-Chair for Food (By-) Products Valorization Technologies of the Estonian University of Life Sciences (VALORTECH) which has received funding from the European Union’s Horizon 2020 research and innovation program under grant agreement No 810630.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'VALORTECH'  ->  SIMPLE_CHEMICAL  [141:150]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'VALORTECH' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 13: haussknechtii was evaluated against different breast cancer cell lines, to determine invasion, adhesion, and lipid peroxidation.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'breast cancer'  ->  DISEASE  [46:59]
#
#   [scispacy_jnlpba]  (1 entities)
#       'breast cancer cell lines'  ->  CELL_LINE  [46:70]
#
#   [scispacy_bionlp13cg]  (2 entities)
#       'breast cancer cell lines'  ->  CELL  [46:70]
#       'lipid'  ->  SIMPLE_CHEMICAL  [109:114]
#
#   [hunflair2]  (2 entities)
#       'haussknechtii'  ->  Species  conf=1.0  [0:13]
#       'breast cancer'  ->  Disease  conf=1.0  [46:59]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'lipid' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#       'haussknechtii' (Species) — only hunflair2
#
# ====================================================================================================
# SENTENCE 14: The isolation, purification and safety efficacy of these compounds obtained from natural resources is a vital criterion that needs to be considered.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 15: Liposarcoma (LS) is associated with considerable morbidity and mortality and particularly poor prognosis, due to local recurrence and tendency to metastasize to the lungs and liver.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'Liposarcoma'  ->  DISEASE  [0:11]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (3 entities)
#       'Liposarcoma'  ->  CANCER  [0:11]
#       'lungs'  ->  ORGAN  [165:170]
#       'liver'  ->  ORGAN  [175:180]
#
#   [hunflair2]  (2 entities)
#       'Liposarcoma'  ->  Disease  conf=1.0  [0:11]
#       'LS'  ->  Disease  conf=1.0  [13:15]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'lungs' (ORGAN) — only scispacy_bionlp13cg
#       'liver' (ORGAN) — only scispacy_bionlp13cg
#       'LS' (Disease) — only hunflair2
#
# ====================================================================================================
# SENTENCE 16: A combinatorial approach was reported to develop nanoemulsion-based delivery systems containing imiquimod in combination with curcumin to improve the topical delivery of these bioactive compounds.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (2 entities)
#       'imiquimod'  ->  CHEMICAL  [96:105]
#       'curcumin'  ->  CHEMICAL  [126:134]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (2 entities)
#       'imiquimod'  ->  SIMPLE_CHEMICAL  [96:105]
#       'curcumin'  ->  SIMPLE_CHEMICAL  [126:134]
#
#   [hunflair2]  (2 entities)
#       'imiquimod'  ->  Chemical  conf=1.0  [96:105]
#       'curcumin'  ->  Chemical  conf=1.0  [126:134]
#
# ====================================================================================================
# SENTENCE 17: The efficacy of these bioactives can often be improved by encapsulating them in nanobased-formulations designed for application in the agriculture, food, pharmaceutical industries.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'nanobased-formulations'  ->  CANCER  [80:102]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'nanobased-formulations' (CANCER) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 18: Arg Extracts: Chemical Profiles, Biological Abilities, Network Analysis and Molecular Docking Development of Biodegradable Agar-Agar/Gelatin-Based Superabsorbent Hydrogel as an Efficient Moisture-Retaining Agent Detection and Characterization of Antibacterial Siderophores Secreted by Endophytic Fungi from Cymbidium aloifolium Anti-Bacterial and Anti-Candidal Activity of Silver Nanoparticles Biosynthesized Using Citrobacter spp.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (2 entities)
#       'Silver'  ->  CHEMICAL  [373:379]
#       'Citrobacter'  ->  DISEASE  [415:426]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (5 entities)
#       'Arg Extracts'  ->  GENE_OR_GENE_PRODUCT  [0:12]
#       'Siderophores Secreted by Endophytic Fungi'  ->  GENE_OR_GENE_PRODUCT  [260:301]
#       'Cymbidium aloifolium'  ->  ORGANISM  [307:327]
#       'Anti-Candidal'  ->  GENE_OR_GENE_PRODUCT  [347:360]
#       'Citrobacter'  ->  SIMPLE_CHEMICAL  [415:426]
#
#   [hunflair2]  (4 entities)
#       'Agar-Agar'  ->  Chemical  conf=1.0  [123:132]
#       'Gelatin-Based'  ->  Chemical  conf=0.999  [133:146]
#       'Cymbidium aloifolium'  ->  Species  conf=1.0  [307:327]
#       'Silver'  ->  Chemical  conf=1.0  [373:379]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'Arg Extracts' (GENE_OR_GENE_PRODUCT) — only scispacy_bionlp13cg
#       'Siderophores Secreted by Endophytic Fungi' (GENE_OR_GENE_PRODUCT) — only scispacy_bionlp13cg
#       'Anti-Candidal' (GENE_OR_GENE_PRODUCT) — only scispacy_bionlp13cg
#       'Agar-Agar' (Chemical) — only hunflair2
#       'Gelatin-Based' (Chemical) — only hunflair2
#
# ====================================================================================================
# SENTENCE 19: Overall, this Special Issue has demonstrated the potential of a broad range of bioactive molecules isolated from plant-based materials to improve human health and well-being, as well as the potentiality for nanotechnology to improve the efficacy of these bioactive molecules.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'human health'  ->  ORGANISM  [146:158]
#
#   [hunflair2]  (1 entities)
#       'human'  ->  Species  conf=1.0  [146:151]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'human health' (ORGANISM) — only scispacy_bionlp13cg
#       'human' (Species) — only hunflair2
#
# ====================================================================================================
# SENTENCE 20: Additionally, these extracts showed good cytotoxic activity against human hepatocellular carcinoma cells.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'human hepatocellular carcinoma'  ->  DISEASE  [68:98]
#
#   [scispacy_jnlpba]  (1 entities)
#       'human hepatocellular carcinoma cells'  ->  CELL_LINE  [68:104]
#
#   [scispacy_bionlp13cg]  (2 entities)
#       'extracts'  ->  ORGANISM_SUBSTANCE  [20:28]
#       'human hepatocellular carcinoma cells'  ->  ORGANISM  [68:104]
#
#   [hunflair2]  (2 entities)
#       'human'  ->  Species  conf=1.0  [68:73]
#       'hepatocellular carcinoma'  ->  Disease  conf=1.0  [74:98]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'human hepatocellular carcinoma' (DISEASE) — only scispacy_bc5cdr
#       'extracts' (ORGANISM_SUBSTANCE) — only scispacy_bionlp13cg
#       'human' (Species) — only hunflair2
#       'hepatocellular carcinoma' (Disease) — only hunflair2
#
# ====================================================================================================
# SENTENCE 21: On the other hand, Chaudhary et al.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 22: According to U.S. Breast Cancer statistics, one out of every eight women will suffer breast cancer at certain times of her life.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (2 entities)
#       'Breast Cancer'  ->  DISEASE  [18:31]
#       'breast cancer'  ->  DISEASE  [85:98]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (3 entities)
#       'Breast Cancer'  ->  CANCER  [18:31]
#       'women'  ->  ORGANISM  [67:72]
#       'breast cancer'  ->  CANCER  [85:98]
#
#   [hunflair2]  (3 entities)
#       'Breast Cancer'  ->  Disease  conf=1.0  [18:31]
#       'women'  ->  Species  conf=1.0  [67:72]
#       'breast cancer'  ->  Disease  conf=1.0  [85:98]
#
# ====================================================================================================
# SENTENCE 23: Hence, there is a marked need to explore much more effective and nontoxic antineoplastic drugs to enhance locoregional disease control and overall survival in sarcoma patients.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'sarcoma'  ->  DISEASE  [159:166]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'sarcoma patients'  ->  CANCER  [159:175]
#
#   [hunflair2]  (2 entities)
#       'sarcoma'  ->  Disease  conf=1.0  [159:166]
#       'patients'  ->  Species  conf=1.0  [167:175]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'sarcoma patients' (CANCER) — only scispacy_bionlp13cg
#       'patients' (Species) — only hunflair2
#
# ====================================================================================================
# SENTENCE 24: The microencapsulated samples exhibited no sign of cytotoxicity in a cell culture model.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'cell'  ->  CELL  [69:73]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'cell' (CELL) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 25: The optimum concentration of the extract was ascertained based on apoptotic activity, invasion, adhesion, and lipid peroxidation assays.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'lipid'  ->  SIMPLE_CHEMICAL  [110:115]
#
#   [hunflair2]  (1 entities)
#       'lipid peroxidation'  ->  Chemical  conf=0.764  [110:128]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'lipid' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#       'lipid peroxidation' (Chemical) — only hunflair2
#
# ====================================================================================================
# SENTENCE 26: Bio-pharmacological effects of the extracts were ascertained and the potential mechanisms of action of the bioactive compounds in this medicinal plant were investigated using docking analysis.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (1 entities)
#       'Bio-pharmacological'  ->  PROTEIN  [0:19]
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'extracts'  ->  ORGANISM_SUBSTANCE  [35:43]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'Bio-pharmacological' (PROTEIN) — only scispacy_jnlpba
#       'extracts' (ORGANISM_SUBSTANCE) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 27: The findings illustrated that 6-Shogaol to have strong antigrowth and pro-apoptotic effects on SW872 cells by regulating the intrinsic caspase pathway, oxidative stress, STAT-3, AMPK, and ER stress.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       '6-Shogaol'  ->  CHEMICAL  [30:39]
#
#   [scispacy_jnlpba]  (3 entities)
#       'SW872 cells'  ->  CELL_LINE  [95:106]
#       'STAT-3'  ->  PROTEIN  [170:176]
#       'ER'  ->  PROTEIN  [188:190]
#
#   [scispacy_bionlp13cg]  (6 entities)
#       '6-Shogaol'  ->  SIMPLE_CHEMICAL  [30:39]
#       'SW872 cells'  ->  CELL  [95:106]
#       'caspase'  ->  GENE_OR_GENE_PRODUCT  [135:142]
#       'STAT-3'  ->  GENE_OR_GENE_PRODUCT  [170:176]
#       'AMPK'  ->  GENE_OR_GENE_PRODUCT  [178:182]
#       'ER'  ->  GENE_OR_GENE_PRODUCT  [188:190]
#
#   [hunflair2]  (5 entities)
#       '6-Shogaol'  ->  Chemical  conf=1.0  [30:39]
#       'SW872'  ->  CellLine  conf=0.995  [95:100]
#       'caspase'  ->  Gene  conf=1.0  [135:142]
#       'STAT-3'  ->  Gene  conf=1.0  [170:176]
#       'AMPK'  ->  Gene  conf=1.0  [178:182]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'SW872' (CellLine) — only hunflair2
#
# ====================================================================================================
# SENTENCE 28: Clearly, this is an important area and there is need for much more research to be undertaken in the future to identify other kinds of bioactive molecules and nanoparticle-based delivery systems and prove their efficacy.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (1 entities)
#       'bioactive molecules'  ->  PROTEIN  [134:153]
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'bioactive molecules' (PROTEIN) — only scispacy_jnlpba
#
# ====================================================================================================
# SENTENCE 29: Nanotechnology has been used to create topical delivery systems for enhancing the utilization and efficacy of bioactivities.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 30: Informed Consent Statement Not applicable.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 31: This study claimed that the combination of curcumin and imiquimod in the nanoemulgel system to prevent the appearance of psoriasis-like symptoms compared with the imiquimod nanoemulgel and imiquimod gel formulation alone.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (4 entities)
#       'curcumin'  ->  CHEMICAL  [43:51]
#       'imiquimod'  ->  CHEMICAL  [56:65]
#       'imiquimod'  ->  CHEMICAL  [163:172]
#       'imiquimod'  ->  CHEMICAL  [189:198]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (4 entities)
#       'curcumin'  ->  SIMPLE_CHEMICAL  [43:51]
#       'imiquimod'  ->  SIMPLE_CHEMICAL  [56:65]
#       'imiquimod'  ->  SIMPLE_CHEMICAL  [163:172]
#       'imiquimod'  ->  SIMPLE_CHEMICAL  [189:198]
#
#   [hunflair2]  (5 entities)
#       'curcumin'  ->  Chemical  conf=1.0  [43:51]
#       'imiquimod'  ->  Chemical  conf=1.0  [56:65]
#       'psoriasis-like'  ->  Disease  conf=1.0  [121:135]
#       'imiquimod'  ->  Chemical  conf=1.0  [163:172]
#       'imiquimod'  ->  Chemical  conf=1.0  [189:198]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'psoriasis-like' (Disease) — only hunflair2
#
# ====================================================================================================
# SENTENCE 32: The ellagic acid-loaded microgels, which were formed from calcium pectinate, were shown to significantly improve the gastric ulcer index in rats when compared with native ellagic acid.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (4 entities)
#       'ellagic acid-loaded'  ->  CHEMICAL  [4:23]
#       'calcium'  ->  CHEMICAL  [58:65]
#       'ulcer'  ->  DISEASE  [125:130]
#       'ellagic acid'  ->  CHEMICAL  [171:183]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (5 entities)
#       'acid-loaded'  ->  SIMPLE_CHEMICAL  [12:23]
#       'calcium'  ->  SIMPLE_CHEMICAL  [58:65]
#       'gastric ulcer'  ->  CANCER  [117:130]
#       'rats'  ->  ORGANISM  [140:144]
#       'ellagic'  ->  SIMPLE_CHEMICAL  [171:178]
#
#   [hunflair2]  (5 entities)
#       'ellagic acid-loaded'  ->  Chemical  conf=1.0  [4:23]
#       'calcium pectinate'  ->  Chemical  conf=1.0  [58:75]
#       'gastric ulcer'  ->  Disease  conf=1.0  [117:130]
#       'rats'  ->  Species  conf=0.999  [140:144]
#       'ellagic acid'  ->  Chemical  conf=1.0  [171:183]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'ulcer' (DISEASE) — only scispacy_bc5cdr
#       'acid-loaded' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#       'ellagic' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#       'calcium pectinate' (Chemical) — only hunflair2
#
# ====================================================================================================
# SENTENCE 33: Conflicts of Interest The authors declare no conflict of interest.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 34: Bio-Based Formulations for Sustainable Applications in Agri-Food-Pharma Currently, there is a strong enduring interest towards obtaining high-value, sustainable bio-based bioactive compounds from natural resources, as there is great demand for these compounds in various market sectors such as agriculture, food, pharma, cosmeceuticals, and others.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'Agri-Food-Pharma'  ->  CHEMICAL  [55:71]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'Agri-Food-Pharma'  ->  GENE_OR_GENE_PRODUCT  [55:71]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 35: Some case studies have been discussed in the below text.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 36: to enhance its controlled release in the alimentary tract to treat peptic ulcers.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (2 entities)
#       'alimentary tract'  ->  ORGANISM_SUBDIVISION  [41:57]
#       'ulcers'  ->  PATHOLOGICAL_FORMATION  [74:80]
#
#   [hunflair2]  (1 entities)
#       'peptic ulcers'  ->  Disease  conf=1.0  [67:80]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'alimentary tract' (ORGANISM_SUBDIVISION) — only scispacy_bionlp13cg
#       'ulcers' (PATHOLOGICAL_FORMATION) — only scispacy_bionlp13cg
#       'peptic ulcers' (Disease) — only hunflair2
#
# ====================================================================================================
# SENTENCE 37: The AgNPs were reported to exhibit high antifungal activity towards pathogenic Candida spp.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (2 entities)
#       'AgNPs'  ->  CHEMICAL  [4:9]
#       'Candida spp'  ->  DISEASE  [79:90]
#
#   [scispacy_jnlpba]  (1 entities)
#       'AgNPs'  ->  CELL_LINE  [4:9]
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (1 entities)
#       'Candida spp'  ->  Species  conf=0.996  [79:90]
#
# ====================================================================================================
# SENTENCE 38: This study revealed that 6-Shogaol to inhibit the growth of both cell types without affecting the normal cell lines (normal 3T3-L1 preadipocytes).
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       '6-Shogaol'  ->  CHEMICAL  [25:34]
#
#   [scispacy_jnlpba]  (2 entities)
#       'normal cell lines'  ->  CELL_LINE  [98:115]
#       'normal 3T3-L1 preadipocytes'  ->  CELL_LINE  [117:144]
#
#   [scispacy_bionlp13cg]  (4 entities)
#       '6-Shogaol'  ->  SIMPLE_CHEMICAL  [25:34]
#       'cell'  ->  CELL  [65:69]
#       'cell lines'  ->  CELL  [105:115]
#       '3T3-L1 preadipocytes'  ->  CELL  [124:144]
#
#   [hunflair2]  (2 entities)
#       '6-Shogaol'  ->  Chemical  conf=1.0  [25:34]
#       '3T3-L1'  ->  CellLine  conf=0.605  [124:130]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'normal cell lines' (CELL_LINE) — only scispacy_jnlpba
#       'normal 3T3-L1 preadipocytes' (CELL_LINE) — only scispacy_jnlpba
#       'cell' (CELL) — only scispacy_bionlp13cg
#       'cell lines' (CELL) — only scispacy_bionlp13cg
#       '3T3-L1 preadipocytes' (CELL) — only scispacy_bionlp13cg
#       '3T3-L1' (CellLine) — only hunflair2
#
# ====================================================================================================
# SENTENCE 39: As per the information available, several researchers have documented their work on the potentiality of biobased bioactive compounds obtained from plant, animal or microbial resources, who have developed the nanoformulations by using different encapsulation strategies for the effective delivery of these compounds at targeted sites.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 40: The peptides contained some specific binding sites for flavonoids and revealed the involvement of hydrogen bonds and weak van der Waal interactions in microcapsule formulation.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'flavonoids'  ->  CHEMICAL  [55:65]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (3 entities)
#       'flavonoids'  ->  SIMPLE_CHEMICAL  [55:65]
#       'hydrogen'  ->  SIMPLE_CHEMICAL  [98:106]
#       'microcapsule'  ->  SIMPLE_CHEMICAL  [151:163]
#
#   [hunflair2]  (2 entities)
#       'flavonoids'  ->  Chemical  conf=1.0  [55:65]
#       'hydrogen'  ->  Chemical  conf=1.0  [98:106]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'microcapsule' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 41: Despite the development and clinical utilization of new targeted chemotherapeutic agents, improved radiation targeting, and surgical techniques, only a small increase in overall survival of sarcoma patients’ have been demonstrated over the last two decades.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (2 entities)
#       'sarcoma'  ->  DISEASE  [190:197]
#       '’'  ->  DISEASE  [206:207]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'sarcoma patients'  ->  CANCER  [190:206]
#
#   [hunflair2]  (2 entities)
#       'sarcoma'  ->  Disease  conf=1.0  [190:197]
#       'patients’'  ->  Species  conf=0.866  [198:207]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       '’' (DISEASE) — only scispacy_bc5cdr
#       'sarcoma patients' (CANCER) — only scispacy_bionlp13cg
#       'patients’' (Species) — only hunflair2
#
# ====================================================================================================
# SENTENCE 42: Funding V.K.G. would like to acknowledge the institutional research funding supported by the Scotland’s Rural College (SRUC), UK.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (2 entities)
#       'SRUC'  ->  CANCER  [119:123]
#       'UK'  ->  GENE_OR_GENE_PRODUCT  [126:128]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'SRUC' (CANCER) — only scispacy_bionlp13cg
#       'UK' (GENE_OR_GENE_PRODUCT) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 43: Publisher’s Note: MDPI stays neutral with regard to jurisdictional claims in published maps and institutional affiliations.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'MDPI'  ->  CHEMICAL  [18:22]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'MDPI'  ->  SIMPLE_CHEMICAL  [18:22]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 44: On the other note, nanotechnology applications are being used to convert antioxidant and antimicrobial rich essential oils into water-dispersible forms, thereby enhancing their efficacy.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (2 entities)
#       'essential oils'  ->  Chemical  conf=1.0  [108:122]
#       'water-dispersible'  ->  Chemical  conf=1.0  [128:145]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'essential oils' (Chemical) — only hunflair2
#       'water-dispersible' (Chemical) — only hunflair2
#
# ====================================================================================================
# SENTENCE 45: This Special Issue, “Bioactive Formulations in Agri-Food-Pharma: Source and Applications”, has aimed to gather knowledge on recent advancements in the formulation of nano-delivery systems of novel bioactive compounds using advanced nano-engineered strategies.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'Agri-Food-Pharma'  ->  CHEMICAL  [47:63]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'Agri-Food-Pharma' (CHEMICAL) — only scispacy_bc5cdr
#
# ====================================================================================================
# SENTENCE 46: These silver nanoparticles effectively inhibited bacterial growth in a dose-dependent manner.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'silver'  ->  CHEMICAL  [6:12]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (1 entities)
#       'silver'  ->  Chemical  conf=1.0  [6:12]
#
# ====================================================================================================
# SENTENCE 47: optimized an eco-friendly approach to synthesize AgNPs using endophytic bacteria (Cytobacillus firmus) isolated from the stem bark of Terminalia arjuna.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (2 entities)
#       'AgNPs'  ->  CHEMICAL  [49:54]
#       'Cytobacillus firmus'  ->  DISEASE  [82:101]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (2 entities)
#       'stem bark'  ->  CELL  [121:130]
#       'Terminalia arjuna'  ->  CELL  [134:151]
#
#   [hunflair2]  (3 entities)
#       'AgNPs'  ->  Chemical  conf=1.0  [49:54]
#       'Cytobacillus firmus'  ->  Species  conf=1.0  [82:101]
#       'Terminalia arjuna'  ->  Species  conf=1.0  [134:151]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'stem bark' (CELL) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 48: This study showed that novel moisture retaining agents for soil, which are biodegradable, non-toxic, and of low-cost may be developed and applied in areas where water scarcity occurs.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 49: These delivery systems can be designed to increase the dispersibility, stability, bioavailability, and bioactivity imparted by the bioactives.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 50: Researchers have shown that capsaicin can inhibit the growth of some important food-borne pathogenic microorganisms, such as Listeria monocytogenes, Helicobacter pylori, Pseudomonas aeruginosa, Botrytis cinerea, Aspergillus niger, Staphylococcus aureus and Penicillium expansum.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (6 entities)
#       'capsaicin'  ->  CHEMICAL  [28:37]
#       'food-borne'  ->  DISEASE  [79:89]
#       'Listeria'  ->  DISEASE  [125:133]
#       'Helicobacter pylori'  ->  DISEASE  [149:168]
#       'aeruginosa'  ->  DISEASE  [182:192]
#       'Botrytis cinerea'  ->  DISEASE  [194:210]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (5 entities)
#       'capsaicin'  ->  SIMPLE_CHEMICAL  [28:37]
#       'Listeria monocytogenes'  ->  CELLULAR_COMPONENT  [125:147]
#       'Helicobacter pylori'  ->  ORGANISM  [149:168]
#       'Botrytis cinerea'  ->  CELL  [194:210]
#       'Penicillium expansum.'  ->  GENE_OR_GENE_PRODUCT  [257:278]
#
#   [hunflair2]  (8 entities)
#       'capsaicin'  ->  Chemical  conf=1.0  [28:37]
#       'Listeria monocytogenes'  ->  Species  conf=1.0  [125:147]
#       'Helicobacter pylori'  ->  Species  conf=1.0  [149:168]
#       'Pseudomonas aeruginosa'  ->  Species  conf=1.0  [170:192]
#       'Botrytis cinerea'  ->  Species  conf=1.0  [194:210]
#       'Aspergillus niger'  ->  Species  conf=1.0  [212:229]
#       'Staphylococcus aureus'  ->  Species  conf=1.0  [231:252]
#       'Penicillium expansum'  ->  Species  conf=1.0  [257:277]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'food-borne' (DISEASE) — only scispacy_bc5cdr
#       'Listeria' (DISEASE) — only scispacy_bc5cdr
#       'aeruginosa' (DISEASE) — only scispacy_bc5cdr
#       'Penicillium expansum.' (GENE_OR_GENE_PRODUCT) — only scispacy_bionlp13cg
#       'Pseudomonas aeruginosa' (Species) — only hunflair2
#       'Aspergillus niger' (Species) — only hunflair2
#       'Staphylococcus aureus' (Species) — only hunflair2
#       'Penicillium expansum' (Species) — only hunflair2
#
# ====================================================================================================
# SENTENCE 51: isolated bioactive siderophores from endophytic fungi obtained from Cymbidium aloifolium (medicinal orchid plant) and studied their potential application as antimicrobial agents against phytopathogens in crop plants.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'Cymbidium aloifolium'  ->  ORGANISM  [68:88]
#
#   [hunflair2]  (1 entities)
#       'Cymbidium aloifolium'  ->  Species  conf=1.0  [68:88]
#
# ====================================================================================================
# SENTENCE 52: The bioactive molecules are partly or wholly derived from resources of biological origin mainly those of plants, animal and microbial resources (e.g., biomass/feed stock from agri-food sector, food wastes and by-products, algae, marine organisms, etc.).
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (3 entities)
#       'biomass/feed'  ->  CANCER  [151:163]
#       'by-products'  ->  SIMPLE_CHEMICAL  [209:220]
#       'algae'  ->  CELLULAR_COMPONENT  [222:227]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ...
#       'GE-co-MA'  ->  Chemical  conf=1.0  [13:21]
#       'AA'  ->  Chemical  conf=1.0  [22:24]
#       'water'  ->  Chemical  conf=1.0  [69:74]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'Agr/GE-co-MA/AA hydrogels' (CELL_LINE) — only scispacy_jnlpba
#       'Agr' (Gene) — only hunflair2
#       'GE-co-MA' (Chemical) — only hunflair2
#       'AA' (Chemical) — only hunflair2
#       'water' (Chemical) — only hunflair2
#
# ====================================================================================================
# SENTENCE 87: In addition, 6-Shogaol also upregulated the expression and phosphorylation of GRP-78, eIF-2α, ATF4, and CHOP, which are known ER stress markers in SW872 cells, illustrating the induction of ER stress.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (5 entities)
#       'GRP-78'  ->  PROTEIN  [78:84]
#       'ATF4'  ->  PROTEIN  [94:98]
#       'ER stress markers'  ->  PROTEIN  [126:143]
#       'SW872 cells'  ->  CELL_LINE  [147:158]
#       'ER'  ->  PROTEIN  [190:192]
#
#   [scispacy_bionlp13cg]  (7 entities)
#       '6-Shogaol'  ->  SIMPLE_CHEMICAL  [13:22]
#       'GRP-78'  ->  GENE_OR_GENE_PRODUCT  [78:84]
#       'ATF4'  ->  GENE_OR_GENE_PRODUCT  [94:98]
#       'CHOP'  ->  SIMPLE_CHEMICAL  [104:108]
#       'ER'  ->  GENE_OR_GENE_PRODUCT  [126:128]
#       'SW872 cells'  ->  CELL  [147:158]
#       'ER'  ->  GENE_OR_GENE_PRODUCT  [190:192]
#
#   [hunflair2]  (6 entities)
#       '6-Shogaol'  ->  Chemical  conf=1.0  [13:22]
#       'GRP-78'  ->  Gene  conf=1.0  [78:84]
#       'eIF-2α'  ->  Gene  conf=1.0  [86:92]
#       'ATF4'  ->  Gene  conf=1.0  [94:98]
#       'CHOP'  ->  Gene  conf=1.0  [104:108]
#       'SW872'  ->  CellLine  conf=0.995  [147:152]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'ER stress markers' (PROTEIN) — only scispacy_jnlpba
#       'ER' (GENE_OR_GENE_PRODUCT) — only scispacy_bionlp13cg
#       'eIF-2α' (Gene) — only hunflair2
#       'SW872' (CellLine) — only hunflair2
#
# ====================================================================================================
# SENTENCE 88: A pharmaceutical carbopol-based formulation containing capsaicin extracted from Capsicum annuum fruits, was synthesized by Goci et al.,
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'capsaicin'  ->  CHEMICAL  [55:64]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (3 entities)
#       'carbopol-based'  ->  SIMPLE_CHEMICAL  [17:31]
#       'capsaicin'  ->  SIMPLE_CHEMICAL  [55:64]
#       'Capsicum annuum fruits'  ->  CELL  [80:102]
#
#   [hunflair2]  (2 entities)
#       'carbopol-based'  ->  Chemical  conf=1.0  [17:31]
#       'capsaicin'  ->  Chemical  conf=1.0  [55:64]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'Capsicum annuum fruits' (CELL) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 89: Author Contributions Conceptualization, M.S., and V.K.G.; writing—original draft preparation, M.S., and V.K.G.; writing—review and editing, M.S., R.B., Z.U., D.J.M., P.S., V.B.R., and V.K.G. All authors have read and agreed to the published version of the manuscript.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (4 entities)
#       'V.K.G.'  ->  ORGANISM  [50:56]
#       'V.K.G.'  ->  ORGANISM  [104:110]
#       'D.J.M.'  ->  GENE_OR_GENE_PRODUCT  [158:164]
#       'V.K.G.'  ->  GENE_OR_GENE_PRODUCT  [184:190]
#
#   [hunflair2]  (0 entities)
#       (none found)
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'V.K.G.' (ORGANISM) — only scispacy_bionlp13cg
#       'V.K.G.' (ORGANISM) — only scispacy_bionlp13cg
#       'D.J.M.' (GENE_OR_GENE_PRODUCT) — only scispacy_bionlp13cg
#       'V.K.G.' (GENE_OR_GENE_PRODUCT) — only scispacy_bionlp13cg
#
# ====================================================================================================
# SENTENCE 90: Results of this study showed good antimicrobial and antifungal activities against Gram-positive (Staphylococcus aureus) and Gram-negative (Escherichia coli) bacteria, as well as pearl millet blast disease-causing fungi (Magnoporthe grisea).
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (1 entities)
#       'Gram-positive (Staphylococcus aureus) and Gram-negative'  ->  PROTEIN  [82:137]
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'Escherichia coli'  ->  ORGANISM  [139:155]
#
#   [hunflair2]  (4 entities)
#       'Staphylococcus aureus'  ->  Species  conf=1.0  [97:118]
#       'Escherichia coli'  ->  Species  conf=1.0  [139:155]
#       'pearl millet'  ->  Species  conf=0.966  [178:190]
#       'Magnoporthe grisea'  ->  Species  conf=1.0  [220:238]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'Gram-positive (Staphylococcus aureus) and Gram-negative' (PROTEIN) — only scispacy_jnlpba
#       'Staphylococcus aureus' (Species) — only hunflair2
#       'pearl millet' (Species) — only hunflair2
#       'Magnoporthe grisea' (Species) — only hunflair2
#
# ====================================================================================================
# SENTENCE 91: The ability of hemp essential oil as act as an antimicrobial, anti-leishmanial and antioxidant agent has been reported recently by Menghini et al.. The essential oils of three different cultivars of hemp (Futura 75, Carmagnola selezionata and Eletta campana), were evaluated for their antiprotozoal efficacy by administering them to mice intraperitoneally, which had initially been infected with Leishmania tropica.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'Leishmania tropica'  ->  DISEASE  [396:414]
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (3 entities)
#       'oil'  ->  ORGANISM_SUBSTANCE  [30:33]
#       'Futura'  ->  SIMPLE_CHEMICAL  [205:211]
#       'mice'  ->  ORGANISM  [333:337]
#
#   [hunflair2]  (7 entities)
#       'hemp essential oil'  ->  Chemical  conf=1.0  [15:33]
#       'essential oils'  ->  Chemical  conf=0.996  [152:166]
#       'hemp'  ->  Species  conf=0.842  [199:203]
#       'Carmagnola selezionata'  ->  Species  conf=0.996  [216:238]
#       'Eletta campana'  ->  Species  conf=0.97  [243:257]
#       'mice'  ->  Species  conf=1.0  [333:337]
#       'Leishmania tropica'  ->  Species  conf=1.0  [396:414]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'oil' (ORGANISM_SUBSTANCE) — only scispacy_bionlp13cg
#       'Futura' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#       'hemp essential oil' (Chemical) — only hunflair2
#       'essential oils' (Chemical) — only hunflair2
#       'hemp' (Species) — only hunflair2
#       'Carmagnola selezionata' (Species) — only hunflair2
#       'Eletta campana' (Species) — only hunflair2
#
# ====================================================================================================
# SENTENCE 92: These molecules have recently emerged on the global market as a highly reliable environmentally friendly alternative to chemically synthesized compounds.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 93: The authors reported that Penicillium chrysogenum to be the best among all of the tested fungi and may be utilized in the form of bioactive formulations for development of resistance against other phytopathogens in crop plants.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'Penicillium chrysogenum'  ->  SIMPLE_CHEMICAL  [26:49]
#
#   [hunflair2]  (1 entities)
#       'Penicillium chrysogenum'  ->  Species  conf=1.0  [26:49]
#
# ====================================================================================================
# SENTENCE 94: The mechanism of action underlying was elucidated along with the observed anti-proliferative effects, which caused tumoral cell death, but without any cytotoxic effects on human healthy breast cells.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'tumoral cell death'  ->  DISEASE  [115:133]
#
#   [scispacy_jnlpba]  (1 entities)
#       'human healthy breast cells'  ->  CELL_TYPE  [172:198]
#
#   [scispacy_bionlp13cg]  (3 entities)
#       'tumoral cell'  ->  CELL  [115:127]
#       'human'  ->  ORGANISM  [172:177]
#       'breast cells'  ->  CELL  [186:198]
#
#   [hunflair2]  (2 entities)
#       'tumoral'  ->  Disease  conf=0.982  [115:122]
#       'human'  ->  Species  conf=1.0  [172:177]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'tumoral cell death' (DISEASE) — only scispacy_bc5cdr
#       'human healthy breast cells' (CELL_TYPE) — only scispacy_jnlpba
#       'tumoral cell' (CELL) — only scispacy_bionlp13cg
#       'breast cells' (CELL) — only scispacy_bionlp13cg
#       'tumoral' (Disease) — only hunflair2
#
# ====================================================================================================
# SENTENCE 95: The authors claimed that β-lactoglobulin and CA were bound to each other through weak Van der Waals’ forces and hydrogen bonding.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (1 entities)
#       'β-lactoglobulin'  ->  CHEMICAL  [25:40]
#
#   [scispacy_jnlpba]  (2 entities)
#       'β-lactoglobulin'  ->  PROTEIN  [25:40]
#       'CA'  ->  PROTEIN  [45:47]
#
#   [scispacy_bionlp13cg]  (3 entities)
#       'β-lactoglobulin'  ->  GENE_OR_GENE_PRODUCT  [25:40]
#       'CA'  ->  GENE_OR_GENE_PRODUCT  [45:47]
#       'hydrogen'  ->  SIMPLE_CHEMICAL  [112:120]
#
#   [hunflair2]  (3 entities)
#       'β-lactoglobulin'  ->  Gene  conf=1.0  [25:40]
#       'CA'  ->  Chemical  conf=0.996  [45:47]
#       'hydrogen'  ->  Chemical  conf=1.0  [112:120]
#
# ====================================================================================================
# SENTENCE 96: The bio-pharmacological activity was exhibited by the compound selina-3,7(11)-diene, which revealed its affinity in the micromolar range towards proliferator-activated receptor α, cannabinoid CB2 receptor and acetylcholinesterase.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (3 entities)
#       'proliferator-activated receptor'  ->  PROTEIN  [145:176]
#       'cannabinoid CB2 receptor'  ->  PROTEIN  [180:204]
#       'acetylcholinesterase'  ->  PROTEIN  [209:229]
#
#   [scispacy_bionlp13cg]  (4 entities)
#       'micromolar'  ->  SIMPLE_CHEMICAL  [120:130]
#       'proliferator-activated receptor'  ->  GENE_OR_GENE_PRODUCT  [145:176]
#       'cannabinoid CB2 receptor'  ->  GENE_OR_GENE_PRODUCT  [180:204]
#       'acetylcholinesterase'  ->  GENE_OR_GENE_PRODUCT  [209:229]
#
#   [hunflair2]  (4 entities)
#       'selina-3,7(11)-diene'  ->  Chemical  conf=1.0  [63:83]
#       'proliferator-activated receptor α'  ->  Gene  conf=1.0  [145:178]
#       'cannabinoid CB2 receptor'  ->  Gene  conf=0.906  [180:204]
#       'acetylcholinesterase'  ->  Gene  conf=1.0  [209:229]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'micromolar' (SIMPLE_CHEMICAL) — only scispacy_bionlp13cg
#       'selina-3,7(11)-diene' (Chemical) — only hunflair2
#       'proliferator-activated receptor α' (Gene) — only hunflair2
#
# ====================================================================================================
# SENTENCE 97: This demand has encouraged researchers to isolate, identify and characterize novel natural bioactive compounds with potential therapeutic and commercial values with industrial importance.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 98: Treatment methods such as surgery, radiation therapy, hormone therapy, chemotherapy, targeted therapy, or herbal treatments are gaining popularity and are continuing to develop rapidly.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (0 entities)
#       (none found)
#
#   [hunflair2]  (0 entities)
#       (none found)
#
# ====================================================================================================
# SENTENCE 99: Treatment options may differ on the basis of stage of the disease, characteristics of the patient, and general health status.
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (0 entities)
#       (none found)
#
#   [scispacy_jnlpba]  (0 entities)
#       (none found)
#
#   [scispacy_bionlp13cg]  (1 entities)
#       'patient'  ->  ORGANISM  [90:97]
#
#   [hunflair2]  (1 entities)
#       'patient'  ->  Species  conf=1.0  [90:97]
#
# ====================================================================================================
# SENTENCE 100: The study by Yadav and Jang investigated the anticancer properties of 6-Shogaol against two different human liposarcoma cell lines (SW872 and 93T449 cells).
# ====================================================================================================
#
#   [scispacy_bc5cdr]  (2 entities)
#       '6-Shogaol'  ->  CHEMICAL  [70:79]
#       'human liposarcoma'  ->  DISEASE  [102:119]
#
#   [scispacy_jnlpba]  (3 entities)
#       'human liposarcoma cell lines'  ->  CELL_LINE  [102:130]
#       'SW872'  ->  CELL_LINE  [132:137]
#       '93T449 cells'  ->  CELL_TYPE  [142:154]
#
#   [scispacy_bionlp13cg]  (5 entities)
#       'anticancer'  ->  CANCER  [45:55]
#       '6-Shogaol'  ->  SIMPLE_CHEMICAL  [70:79]
#       'human liposarcoma cell lines'  ->  ORGANISM  [102:130]
#       'SW872'  ->  CELL  [132:137]
#       '93T449 cells'  ->  CELL  [142:154]
#
#   [hunflair2]  (5 entities)
#       '6-Shogaol'  ->  Chemical  conf=1.0  [70:79]
#       'human'  ->  Species  conf=1.0  [102:107]
#       'liposarcoma'  ->  Disease  conf=1.0  [108:119]
#       'SW872'  ->  CellLine  conf=0.996  [132:137]
#       '93T449'  ->  CellLine  conf=0.996  [142:148]
#
#   --- Caught by only ONE model (possible coverage gap elsewhere) ---
#       'human liposarcoma' (DISEASE) — only scispacy_bc5cdr
#       'anticancer' (CANCER) — only scispacy_bionlp13cg
#       'human' (Species) — only hunflair2
#       'liposarcoma' (Disease) — only hunflair2
#       '93T449' (CellLine) — only hunflair2
#
# ====================================================================================================
# Done.
# ====================================================================================================
